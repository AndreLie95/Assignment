# %%
import numpy as np
import pandas as pd
import scipy.stats as st

# %%
df = pd.read_csv('covid_19_indonesia_time_series_all.csv')
df
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
#        New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0                  0                 2           39            20
# 1                  0                 2           41            20
# 2                  0                 2            2             0
# 3                  0                 1            1             0
# 4                  0                 2           43            20
# ...              ...               ...          ...           ...
# 31817              0                37        52770          1213
# 31818              3                10       104640          2371
# 31819              1                15        82198          3376
# 31820              5                45       158866          3288
# 31821           2997              -666      6405044        157876
#
#        Total Recovered  ...  Latitude New Cases per Million  \
# 0                   75  ... -6.204699                  0.18
# 1                   75  ... -6.204699                  0.18
# 2                    0  ... -0.789275                  0.01
# 3                    1  ...  0.511648                  0.16
# 4                   75  ... -6.204699                  0.18
# ...                ...  ...       ...                   ...
# 31817            50997  ...  1.259638                 14.01
# 31818           102066  ... -0.850253                  2.36
# 31819            78510  ... -3.216212                  1.95
# 31820           154924  ...  2.191894                  3.36
# 31821          6218708  ... -0.789275                  8.89
#
#        Total Cases per Million New Deaths per Million  \
# 0                         3.60                    0.0
# 1                         3.78                    0.0
# 2                         0.01                    0.0
# 3                         0.16                    0.0
# 4                         3.96                    0.0
# ...                        ...                    ...
# 31817                 19974.38                    0.0
# 31818                 18959.11                    0.0
# 31819                 10002.74                    0.0
# 31820                 10680.15                    0.0
# 31821                 24153.07                    0.1
#
#       Total Deaths per Million Total Deaths per 100rb Case Fatality Rate  \
# 0                         1.84                   0.18             51.28%
# 1                         1.84                   0.18             48.78%
# 2                         0.00                   0.00              0.00%
# 3                         0.00                   0.00              0.00%
# 4                         1.84                   0.18             46.51%
# ...                        ...                    ...                ...
# 31817                   459.14                  45.91              2.30%
# 31818                   429.59                  42.96              2.27%
# 31819                   410.83                  41.08              4.11%
# 31820                   221.04                  22.10              2.07%
# 31821                   595.34                  59.53              2.46%
#
#       Case Recovered Rate Growth Factor of New Cases  \
# 0                 192.31%                        NaN
# 1                 182.93%                       1.00
# 2                   0.00%                        NaN
# 3                 100.00%                        NaN
# 4                 174.42%                       1.00
# ...                   ...                        ...
# 31817              96.64%                       2.85
# 31818              97.54%                       6.50
# 31819              95.51%                       3.20
# 31820              97.52%                       1.92
# 31821              97.09%                       0.89
#
#        Growth Factor of New Deaths
# 0                              NaN
# 1                             1.00
# 2                              NaN
# 3                              NaN
# 4                             1.00
# ...                            ...
# 31817                         1.00
# 31818                         1.00
# 31819                         1.00
# 31820                         1.00
# 31821                         1.29
#
# [31822 rows x 38 columns]

# %% [markdown]
# # Hipotesa
# ##### H0 : x_bar presentasi kematian setiap bulan pada tahun 2021 di indonesia <= 50%
# ##### H1 : x_bar presentasi kematian setiap bulan pada tahun 2021 di indonesia > 50%

# %%
df['Case Fatality Rate'] = pd.to_numeric(df['Case Fatality Rate'].str.rstrip('%'))
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df = df[['Date', 'Year', 'Month', 'Location ISO Code', 'Location', 'New Cases', 'New Deaths',
       'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths',
       'Total Recovered', 'Total Active Cases', 'Location Level',
       'City or Regency', 'Province', 'Country', 'Continent', 'Island',
       'Time Zone', 'Special Status', 'Total Regencies', 'Total Cities',
       'Total Districts', 'Total Urban Villages', 'Total Rural Villages',
       'Area (km2)', 'Population', 'Population Density', 'Longitude',
       'Latitude', 'New Cases per Million', 'Total Cases per Million',
       'New Deaths per Million', 'Total Deaths per Million',
       'Total Deaths per 100rb', 'Case Fatality Rate', 'Case Recovered Rate',
       'Growth Factor of New Cases', 'Growth Factor of New Deaths']]

# %%
case_fatality_rate = df[['Year', 'Month', 'Case Fatality Rate']].groupby(['Year', 'Month']).mean()
case_fatality_rate
# Out:
#             Case Fatality Rate
# Year Month
# 2020 3               58.328317
#      4               13.192294
#      5                5.504793
#      6                4.241057
#      7                3.815041
#      8                3.372986
#      9                3.229143
#      10               2.994433
#      11               2.979962
#      12               2.830074
# 2021 1                2.718553
#      2                2.668918
#      3                2.668673
#      4                2.657514
#      5                2.689806
#      6                2.716190
#      7                2.625023
#      8                2.878332
#      9                3.138838
#      10               3.190590
#      11               3.198467
#      12               3.200525
# 2022 1                3.198544
#      2                2.966398
#      3                2.613336
#      4                2.608571
#      5                2.614415
#      6                2.615600
#      7                2.608636
#      8                2.592525
#      9                2.582347

# %%
CL = 95 # Confidence Level = 95%
t_stat, p_val = st.ttest_1samp(case_fatality_rate, 50)
print('P Value:', p_val)
print('T Statistics:', t_stat)
print(f'Alfa: {(100-CL)/100}')
# Out:
# P Value: [1.45804964e-21]
# T Statistics: [-24.83727955]
# Alfa: 0.05

# %% [markdown]
# ## Kesimpulan
# 1. P Value > Alfa = x_bar is not Significant Different (Fail to Reject H0)
# 2. P Value < Alfa = x_bar is Significant different (Reject H0)
# - cause P Value > Alfa :
#         Fail to Reject H0
